# %%
from datetime import datetime
name = "Sofia"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Sofia start programming at 2025-11-07 13:18:18.082723. Lviv is the best city!
